# %%
from platform import python_version

print(python_version())
# Out:
# 3.13.5

# %%
# Save your API key to track your progress and have access to the quantum computers

your_api_key = "Place your api key here"

your_crn = "place your crn here"

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

QiskitRuntimeService.save_account(
    channel="ibm_quantum_platform",
    token=your_api_key,
    instance=your_crn,
    overwrite=True
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from qiskit_ibm_runtime import QiskitRuntimeService
#       3 QiskitRuntimeService.save_account(
#       4     channel="ibm_quantum_platform",
#       5     token=your_api_key,
#       6     instance=your_crn,
#       7     overwrite=True
#       8 )
#
# ModuleNotFoundError: No module named 'qiskit_ibm_runtime'

# %%
# Check that the account has been saved properly
service = QiskitRuntimeService()
service.saved_accounts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Check that the account has been saved properly
# ----> 2 service = QiskitRuntimeService()
#       3 service.saved_accounts()
#
# NameError: name 'QiskitRuntimeService' is not defined

# %%
# Verify
service = QiskitRuntimeService()
backends = service.backends()

print(f"Account OK. {len(backends)} backend(s) available:")
for b in backends[:5]:
    print(f"  {b.name} ({b.num_qubits} qubits)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Verify
# ----> 2 service = QiskitRuntimeService()
#       3 backends = service.backends()
#       5 print(f"Account OK. {len(backends)} backend(s) available:")
#
# NameError: name 'QiskitRuntimeService' is not defined

# %%
# Create a new circuit with a single qubit
from qiskit import QuantumCircuit
qc = QuantumCircuit(2)
# Add a H gate to qubit 0
qc.h(0)
# Add a CNOT gate to qubit 1
qc.cx(0, 1)
# Return a drawing of the circuit using MatPlotLib ("mpl").
qc.draw("mpl")

# %%
# Create a new circuit with three qubits
qc = QuantumCircuit(3)

### WRITE YOUR CODE BELOW HERE ###
# Add a H gate to qubit 0

qc.h(0)

# Add a CNOT gate to qubits 0 and 1

qc.cx(0,1)

# Add a CNOT gate to qubits 1 and 2

qc.cx(1, 2)
### YOUR CODE FINISHES HERE    ###

# Return a drawing of the circuit using MatPlotLib ("mpl").
qc.draw("mpl")
